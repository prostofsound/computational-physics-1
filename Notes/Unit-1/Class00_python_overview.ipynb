# %%
print("Hello World of ecology")
# Out:
# Hello World of ecology

# %% [markdown]
# ## This is a subtitle (use ##)

# %% [markdown]
# 1. This is a list
# 2. second item
# 3. third item

# %% [markdown]
# Now, using indetation:
# * # Topic 1
#     * # Subtopic 1

# %% [markdown]
# Now, we can also insert links:
# [Clic here](https://soundcloud.com/paxmian)

# %% [markdown]
# 1. Get funding
# 2. Do work.
#    * Design experiment.
#    * Collect data.
#    * Analyze.
# 3. Write the algorithm.
# 4. Check the results of each function make sense.
# 5. Run all the code before presenting.
# 6. Analyze and explain the results you obtained.
# 7. Publish

# %%
# This # is used to add a comment in the python language

# To do inline plotting without an environment. It is needed to render plots inside the notebook itself.
# %matplotlib inline

# %%
# Let's make a plot
# Importing libraries
import numpy as np # np is an alias, aliases are used to avoid calling long names
import matplotlib.pyplot as plt # plt is an alias

# Generate a vector for x
x = np.arange(-np.pi, +np.pi, 0.01)

#print(x)

# Plotting (default)
plt.plot(x, np.sin(x))
plt.show()

# %%
# Plotting with dotted line
plt.plot(x, np.sin(x), linestyle = ":", color = "blue")
plt.show()

# %%
# Plotting with markers
plt.plot(x, np.sin(x), linestyle = " ", marker = "d", color = "green")
plt.show()

# %% [markdown]
# # 3D Graphic of a Surface

# %% [markdown]
# Let's make a 3D plot of the following surface:
#
# $z = \sin(\sqrt{x^2+y^2})$

# %%
# Let's define a function using def/return statements

def z_surface(x, y):
  z = np.sin(np.sqrt(x**2 + y**2))
  return z

# %%
# We need to create a mesh grid, for which we first generate 1D vectors
x = np.linspace(-10, 10, 30)
y = np.linspace(-10, 10, 30)

#print(x)
#print(y) #COMMENT THE PRINTS WHEN FINISHED, BUT SHOULD ALWAYS CHECK IF THE OUTPUT MAKES SENSE BEFORE

# %%
# We create a 2D Grid using the vectors above
X_2D, Y_2D = np.meshgrid(x, y)

print(X_2D.shape, Y_2D.shape)
# Out:
# (30, 30) (30, 30)

# %%
# We feed our function:
Z_2D = z_surface(X_2D, Y_2D)

# Checking the shape of the Z array
print(Z_2D.shape)
# Out:
# (30, 30)

# %%
# Plotting with a figure environment
fig = plt.figure()

ax = plt.axes(projection = "3d")
ax.contour3D(X_2D, Y_2D, Z_2D, 500)

plt.show()

# %% [markdown]
# It is important to restart the program and run the code again to check for errors.
