# %% [markdown]
# # Fourier series/expansion
#
# ## Using sympy (symbolic algebra):
#
# We can use the fourier_series() function:
# https://docs.sympy.org/latest/modules/series/fourier.html
#
# ### Example 1:
#
# Calculate the Fourier expansion of:
#
# $f(x) = x^2$

# %%
# Importing libraries

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define symbols
x = sp.symbols('x')

# Function f(x)
y = lambda x: x**2

# Get Fourier series of function
result = sp.fourier_series(x**2, (x, -np.pi, np.pi))

# Same, but using pi from sympy instead of numpy. Sometimes this works better
result1 = sp.fourier_series(x**2, (x, -sp.pi, sp.pi))

# Truncate result to n=3 terms, (recall that the series is infinite)
result_truncated = result.truncate(n=3)
result_truncated1 = result1.truncate(n=3)

# Both show the same result
print(result_truncated)
print()
print(result_truncated1)
# Out:
# -39.4784176043574*cos(0.318309886183791*pi*x)/pi**2 + 9.86960440108936*cos(0.636619772367581*pi*x)/pi**2 + 3.28986813369645
#
# -4*cos(x) + cos(2*x) + pi**2/3

# %%
print(type(result_truncated1))
#print(result_truncated1(x_axis)) # This prints an error
# Out:
# <class 'sympy.core.add.Add'>

# %% [markdown]
# ### Axes:

# %%
# Define the x axis
x_axis = np.arange(-np.pi, np.pi, 0.001)

# We evaluate the y function in our x axis
y_axis = y(x_axis)

# This is wrong
#a = result_truncated1(x_axis)

# This is the correct, this is the way to evaluate a sympy object
y_series1 = sp.lambdify(x, result_truncated1, "numpy")
y_series2 = sp.lambdify(x, result_truncated, "numpy")

print(type(y_series1))
y_eval1 = y_series1(x_axis)
y_eval2 = y_series2(x_axis)
#y_eval = result_truncated1(x_axis)
#print(y_eval)
# Out:
# <class 'function'>

# %% [markdown]
# ### Plotting:

# %%
plt.figure(figsize=(5, 4))

plt.plot(x_axis, y_axis, label = r'$f(x)=x^2$', c ='blue')
plt.plot(x_axis, y_eval1, label = 'Fourier series', c ='red', linestyle = '-.')
# plt.plot(x_axis, y_eval2, label = 'Fourier series', c ='black', linestyle = '-.')

plt.legend()

plt.show()

# %%
# Let's include more terms of the Fourier series

result2 = sp.fourier_series(x**2, (x, -sp.pi, sp.pi))
# print(result2)

result_truncated2 = result2.truncate(n=10) 
print(result_truncated2)

# This is the correct, this is the way to evaluate a sympy object
y_series2 = sp.lambdify(x, result_truncated2, "numpy")

# Evaluate in x axis
y_eval2 = y_series2(x_axis)
# Out:
# -4*cos(x) + cos(2*x) - 4*cos(3*x)/9 + cos(4*x)/4 - 4*cos(5*x)/25 + cos(6*x)/9 - 4*cos(7*x)/49 + cos(8*x)/16 - 4*cos(9*x)/81 + pi**2/3

# %% [markdown]
# We have low and high frequencies. $\textbf{The high frequencies match the borders (the details) and the low frequencies the large scale structures of the function}$.
#
# We have just cos(x) because of the parity of the signal.

# %%
plt.figure(figsize=(5, 4))

plt.plot(x_axis, y_axis, label = r'$f(x)=x^2$', c ='blue')
plt.plot(x_axis, y_eval1, label = 'Fourier series: 3 terms', c ='red', linestyle = '-.')
plt.plot(x_axis, y_eval2, label = 'Fourier series: 10 terms', c ='green', linestyle = '--')

plt.legend()

plt.show()

# %% [markdown]
# ## Example 2:
#
# Calculate the Fourier expansion of:
#
# $f(x) =
# \left\{
#     \begin{array}{lr}
#         0, & -\pi \leq x \leq -\frac{\pi}{2}\\
#         1, & -\frac{\pi}{2} \leq x \leq +\frac{\pi}{2}\\
#         0, & +\frac{\pi}{2} \leq x \leq +\pi
#     \end{array}
# \right\}$

# %%
def function(x):
    """
    This is a piece-wise function for the top-hat function shown above.
    """
    
    if(-np.pi <= x <= -0.5*np.pi):
        return 0

    elif(-0.5*np.pi <= x <= +0.5*np.pi):
        return 1
    
    else:
        return 0

# %% [markdown]
# ### Define axes:

# %%
# X vector
x = np.arange(-np.pi, np.pi, 0.001)

# This is wrong:
#yy = function(x)

# %%
# Empty list (needed)
y = []

# Loop to append the evaluated points
for i in range(len(x)):
    y.append(function(x[i]))

# Convert to an array
y = np.array(y)

# %%
print(x.size, y.size)
# Out:
# 6284 6284

# %% [markdown]
# ### Plotting:

# %%
plt.figure(figsize=(11, 4))

plt.plot(x, y)

plt.xlabel(r"$x$")
plt.ylabel(r"$f(x)$")

plt.show()

# %% [markdown]
# The low spatial frequencies are needed for the flat parts (to match a long wave) and to capture the details we need high spatial frequencies to capture the edges.
#
# In short,
#
# low k $\rightarrow$ long $\lambda$ $\Rightarrow$ large-scale structure
#
# high k $\rightarrow$ short $\lambda$ $\Rightarrow$ small-scale structure

# %% [markdown]
# https://en.wikipedia.org/wiki/Fourier_series

# %%
def function_Fourier(x, n):
    """
    This is a function to calculate the Fourier expansion.
    Inputs: x -> vector for the domain
            n -> the trunction integer
    """
    
    # Empty array
    f = np.zeros(x.size)

    # Add the first term
    f = f + 0.5

    for i in range(1,n+1):
        #print(i)
        y = (2/np.pi)*((-1)**(i-1))*(1/(2*i-1))*np.cos((2*i - 1)*x) #we just include the cos terms since our function is even

        # Adding the next Fourier terms
        f += y 
        
    return f

# %% [markdown]
# ## Plotting

# %%
# Evaluate our Fourier series

fourier_1 = function_Fourier(x, 1)
fourier_2 = function_Fourier(x, 2)
fourier_10 = function_Fourier(x, 10)
fourier_50 = function_Fourier(x, 50)

# %%
plt.figure(figsize=(11, 4))

plt.plot(x, y, c ='blue', label = "f(x)")
plt.plot(x, fourier_1, c = 'pink', label = "1 wave")
plt.plot(x, fourier_2, c = 'red', linestyle =':', label = "2 waves")
plt.plot(x, fourier_10, c = 'red', linestyle ='-', label = "10 waves")
plt.plot(x, fourier_50, c = 'magenta', linestyle ='-.',label = "50 waves")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(5, 4))

plt.plot(x, y, c ='blue')
#plt.plot(x, function_Fourier(x, 1), c = 'red')
#plt.plot(x, function_Fourier(x, 2), c = 'red', linestyle =':')
plt.plot(x, function_Fourier(x, 100), c = 'red', linestyle ='-.')

plt.xlim(1,2)

plt.show()

# %% [markdown]
# ## Piece-wise function using sympy:

# %%
# Define the symbol
xx = sp.Symbol('x')

# Define the piece wise function
phi_1 = sp.Piecewise((0, xx < -sp.pi/2), (0, xx > +sp.pi/2), (1, True))

print(type(phi_1))

# This is converting our sympy object into a numpy one
y_func = sp.lambdify(xx, phi_1, "numpy")

# Evaluate the function using the x vector (we can now do this since its a numpy object now)
y_axis = y_func(x_axis)

print(type(y_func))
# Out:
# Piecewise
# <class 'function'>

# %% [markdown]
# ## Fourier series of piece-wise function:

# %%
# Getting the Fourier series
y_fourier = sp.fourier_series(phi_1, (xx, -sp.pi, sp.pi))

# We truncate it
y_fouriertruncated1 = y_fourier.truncate(n=100)

print(y_fouriertruncated1)
#print(type(y_fouriertruncated1))

# This is converting our sympy object for thr Fourier expansion into a numpy one
y_func2 = sp.lambdify(xx, y_fouriertruncated1, "numpy")

# Evaluate the function using the x vector
y_axis2 = y_func2(x_axis)
# Out:
# 2*cos(x)/pi - 2*cos(3*x)/(3*pi) + 2*cos(5*x)/(5*pi) - 2*cos(7*x)/(7*pi) + 2*cos(9*x)/(9*pi) - 2*cos(11*x)/(11*pi) + 2*cos(13*x)/(13*pi) - 2*cos(15*x)/(15*pi) + 2*cos(17*x)/(17*pi) - 2*cos(19*x)/(19*pi) + 2*cos(21*x)/(21*pi) - 2*cos(23*x)/(23*pi) + 2*cos(25*x)/(25*pi) - 2*cos(27*x)/(27*pi) + 2*cos(29*x)/(29*pi) - 2*cos(31*x)/(31*pi) + 2*cos(33*x)/(33*pi) - 2*cos(35*x)/(35*pi) + 2*cos(37*x)/(37*pi) - 2*cos(39*x)/(39*pi) + 2*cos(41*x)/(41*pi) - 2*cos(43*x)/(43*pi) + 2*cos(45*x)/(45*pi) - 2*cos(47*x)/(47*pi) + 2*cos(49*x)/(49*pi) - 2*cos(51*x)/(51*pi) + 2*cos(53*x)/(53*pi) - 2*cos(55*x)/(55*pi) + 2*cos(57*x)/(57*pi) - 2*cos(59*x)/(59*pi) + 2*cos(61*x)/(61*pi) - 2*cos(63*x)/(63*pi) + 2*cos(65*x)/(65*pi) - 2*cos(67*x)/(67*pi) + 2*cos(69*x)/(69*pi) - 2*cos(71*x)/(71*pi) + 2*cos(73*x)/(73*pi) - 2*cos(75*x)/(75*pi) + 2*cos(77*x)/(77*pi) - 2*cos(79*x)/(79*pi) + 2*cos(81*x)/(81*pi) - 2*cos(83*x)/(83*pi) + 2*cos(85*x)/(85*pi) - 2*cos(87*x)/(87*pi) + 2*cos(89*x)/(89*pi) - 2*cos(91*x)/(91*pi) + 2*cos(93*x)/(93*pi) - 2*cos(95*x)/(95*pi) + 2*cos(97*x)/(97*pi) - 2*cos(99*x)/(99*pi) + 2*cos(101*x)/(101*pi) - 2*cos(103*x)/(103*pi) + 2*cos(105*x)/(105*pi) - 2*cos(107*x)/(107*pi) + 2*cos(109*x)/(109*pi) - 2*cos(111*x)/(111*pi) + 2*cos(113*x)/(113*pi) - 2*cos(115*x)/(115*pi) + 2*cos(117*x)/(117*pi) - 2*cos(119*x)/(119*pi) + 2*cos(121*x)/(121*pi) - 2*cos(123*x)/(123*pi) + 2*cos(125*x)/(125*pi) - 2*cos(127*x)/(127*pi) + 2*cos(129*x)/(129*pi) - 2*cos(131*x)/(131*pi) + 2*cos(133*x)/(133*pi) - 2*cos(135*x)/(135*pi) + 2*cos(137*x)/(137*pi) - 2*cos(139*x)/(139*pi) + 2*cos(141*x)/(141*pi) - 2*cos(143*x)/(143*pi) + 2*cos(145*x)/(145*pi) - 2*cos(147*x)/(147*pi) + 2*cos(149*x)/(149*pi) - 2*cos(151*x)/(151*pi) + 2*cos(153*x)/(153*pi) - 2*cos(155*x)/(155*pi) + 2*cos(157*x)/(157*pi) - 2*cos(159*x)/(159*pi) + 2*cos(161*x)/(161*pi) - 2*cos(163*x)/(163*pi) + 2*cos(165*x)/(165*pi) - 2*cos(167*x)/(167*pi) + 2*cos(169*x)/(169*pi) - 2*cos(171*x)/(171*pi) + 2*cos(173*x)/(173*pi) - 2*cos(175*x)/(175*pi) + 2*cos(177*x)/(177*pi) - 2*cos(179*x)/(179*pi) + 2*cos(181*x)/(181*pi) - 2*cos(183*x)/(183*pi) + 2*cos(185*x)/(185*pi) - 2*cos(187*x)/(187*pi) + 2*cos(189*x)/(189*pi) - 2*cos(191*x)/(191*pi) + 2*cos(193*x)/(193*pi) - 2*cos(195*x)/(195*pi) + 2*cos(197*x)/(197*pi) + 1/2

# %% [markdown]
# ## Plotting:

# %%
plt.figure(figsize=(11, 4))

plt.plot(x_axis, y_axis, c ='blue')
plt.plot(x_axis, y_axis2, c ='red')

plt.show()

# %% [markdown]
# ## Using Riemann sums for the integral definitions:

# %%
def c0():
    c_0 = y_axis
    return c_0.sum()/c_0.size

def cn(n):
    c = y_axis*np.exp(-1j*2*n*np.pi*x_axis/period) #we want to converge to the actual signal, y_axis
    return c.sum()/c.size

def f(x_axis, Nh):
    f = np.array([2*cn(i)*np.exp(1j*2*i*np.pi*x_axis/period) for i in range(1,Nh+1)]) #since our function is even, we sum starting from 0\
    #so, that's were the two factor comes from
    return c0() + f.sum()

# %%
period = 2*np.pi

print(c0())

x_axis = np.arange(-np.pi, np.pi, 0.001)

y_riemann = np.array([f(t,100).real for t in x_axis])
# Out:
# 0.5

# %%
plt.figure(figsize=(11, 4))
plt.plot(x_axis, y_axis, c ='blue')
plt.plot(x_axis, y_riemann, c ='red')
plt.show()
